# %%
# Begin the Challenge 6
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 748

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=b59a0f248a67ea7f00c6fbe29a1eb479"
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=b59a0f248a67ea7f00c6fbe29a1eb479&q=Boston

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather.json()
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 802,
#    'main': 'Clouds',
#    'description': 'scattered clouds',
#    'icon': '03d'}],
#  'base': 'stations',
#  'main': {'temp': 85.01,
#   'feels_like': 86.47,
#   'temp_min': 80.38,
#   'temp_max': 88.61,
#   'pressure': 1010,
#   'humidity': 50},
#  'visibility': 10000,
#  'wind': {'speed': 5.01, 'deg': 288, 'gust': 17},
#  'clouds': {'all': 40},
#  'dt': 1622907669,
#  'sys': {'type': 2,
#   'id': 2013408,
#   'country': 'US',
#   'sunrise': 1622884109,
#   'sunset': 1622938644},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# 6.2.6 using the imports from above start on getting list of cities in groups of 50

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_desc = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_desc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hermanus
# Processing Record 2 of Set 1 | hualmay
# Processing Record 3 of Set 1 | atuona
# Processing Record 4 of Set 1 | vaini
# Processing Record 5 of Set 1 | harlingen
# Processing Record 6 of Set 1 | todos santos
# Processing Record 7 of Set 1 | tiksi
# Processing Record 8 of Set 1 | punta arenas
# Processing Record 9 of Set 1 | carnarvon
# Processing Record 10 of Set 1 | avarua
# Processing Record 11 of Set 1 | mount isa
# Processing Record 12 of Set 1 | saskylakh
# Processing Record 13 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 14 of Set 1 | panaba
# Processing Record 15 of Set 1 | taupo
# Processing Record 16 of Set 1 | ushuaia
# Processing Record 17 of Set 1 | port lincoln
# Processing Record 18 of Set 1 | qaanaaq
# Processing Record 19 of Set 1 | safford
# Processing Record 20 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 21 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 22 of Set 1 | warqla
# City not found. Skipping...
# Processing Record 23 of Set 1 | olafsvik
# Processing Record 24 of Set 1 | makakilo city
# Processing Record 25 of Set 1 | bonfim
# Processing Record 26 of Set 1 | barrow
# Processing Record 27 of Set 1 | aktau
# Processing Record 28 of Set 1 | hithadhoo
# Processing Record 29 of Set 1 | mataura
# Processing Record 30 of Set 1 | hasaki
# Processing Record 31 of Set 1 | vallenar
# Processing Record 32 of Set 1 | skjervoy
# Processing Record 33 of Set 1 | georgetown
# Processing Record 34 of Set 1 | sao sebastiao
# Processing Record 35 of Set 1 | rikitea
# Processing Record 36 of Set 1 | kapaa
# Processing Record 37 of Set 1 | saint george
# Processing Record 38 of Set 1 | sao filipe
# Processing Record 39 of Set 1 | bontang
# Processing Record 40 of Set 1 | san policarpo
# Processing Record 41 of Set 1 | pisco
# Processing Record 42 of Set 1 | guerrero negro
# Processing Record 43 of Set 1 | severo-kurilsk
# Processing Record 44 of Set 1 | nampula
# Processing Record 45 of Set 1 | new norfolk
# Processing Record 46 of Set 1 | troyes
# Processing Record 47 of Set 1 | lebu
# Processing Record 48 of Set 1 | mount gambier
# Processing Record 49 of Set 1 | khatanga
# Processing Record 50 of Set 1 | nizhniy kuranakh
# Processing Record 1 of Set 2 | pochutla
# Processing Record 2 of Set 2 | bambous virieux
# Processing Record 3 of Set 2 | jalu
# Processing Record 4 of Set 2 | bighapur
# Processing Record 5 of Set 2 | nome
# Processing Record 6 of Set 2 | haines junction
# Processing Record 7 of Set 2 | konevo
# Processing Record 8 of Set 2 | french harbor
# Processing Record 9 of Set 2 | cabo san lucas
# Processing Record 10 of Set 2 | fonte boa
# Processing Record 11 of Set 2 | marawi
# Processing Record 12 of Set 2 | kaohsiung
# Processing Record 13 of Set 2 | cabatuan
# Processing Record 14 of Set 2 | bahraich
# Processing Record 15 of Set 2 | yellowknife
# Processing Record 16 of Set 2 | east london
# Processing Record 17 of Set 2 | mitsamiouli
# Processing Record 18 of Set 2 | saint-pierre
# Processing Record 19 of Set 2 | jamestown
# Processing Record 20 of Set 2 | grand gaube
# Processing Record 21 of Set 2 | provideniya
# Processing Record 22 of Set 2 | dunedin
# Processing Record 23 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 24 of Set 2 | mao
# Processing Record 25 of Set 2 | port elizabeth
# Processing Record 26 of Set 2 | talara
# Processing Record 27 of Set 2 | jijiga
# Processing Record 28 of Set 2 | busselton
# Processing Record 29 of Set 2 | villarrobledo
# Processing Record 30 of Set 2 | iguape
# Processing Record 31 of Set 2 | arraial do cabo
# Processing Record 32 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 33 of Set 2 | port alfred
# Processing Record 34 of Set 2 | aubenas
# Processing Record 35 of Set 2 | norman wells
# Processing Record 36 of Set 2 | sorvag
# City not found. Skipping...
# Processing Record 37 of Set 2 | chuy
# Processing Record 38 of Set 2 | fukue
# Processing Record 39 of Set 2 | albany
# Processing Record 40 of Set 2 | bilibino
# Processing Record 41 of Set 2 | cape town
# Processing Record 42 of Set 2 | amos
# Processing Record 43 of Set 2 | ahumada
# City not found. Skipping...
# Processing Record 44 of Set 2 | north bend
# Processing Record 45 of Set 2 | saint-philippe
# Processing Record 46 of Set 2 | yangambi
# Processing Record 47 of Set 2 | ribeira grande
# Processing Record 48 of Set 2 | vostok
# Processing Record 49 of Set 2 | zalantun
# Processing Record 50 of Set 2 | sur
# Processing Record 1 of Set 3 | mandalgovi
# Processing Record 2 of Set 3 | pahrump
# Processing Record 3 of Set 3 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 4 of Set 3 | maldonado
# Processing Record 5 of Set 3 | nikolskoye
# Processing Record 6 of Set 3 | solntsevo
# Processing Record 7 of Set 3 | bluefields
# Processing Record 8 of Set 3 | bredasdorp
# Processing Record 9 of Set 3 | ozinki
# Processing Record 10 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 11 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 12 of Set 3 | asau
# Processing Record 13 of Set 3 | ahipara
# Processing Record 14 of Set 3 | sangar
# Processing Record 15 of Set 3 | tacoaleche
# Processing Record 16 of Set 3 | morgan city
# Processing Record 17 of Set 3 | baffa
# Processing Record 18 of Set 3 | luxor
# Processing Record 19 of Set 3 | amapa
# Processing Record 20 of Set 3 | fomboni
# Processing Record 21 of Set 3 | tara
# Processing Record 22 of Set 3 | puerto ayora
# Processing Record 23 of Set 3 | ballina
# Processing Record 24 of Set 3 | thompson
# Processing Record 25 of Set 3 | mumford
# Processing Record 26 of Set 3 | sitka
# Processing Record 27 of Set 3 | butaritari
# Processing Record 28 of Set 3 | torbay
# Processing Record 29 of Set 3 | antofagasta
# Processing Record 30 of Set 3 | isangel
# Processing Record 31 of Set 3 | mar del plata
# Processing Record 32 of Set 3 | castro
# Processing Record 33 of Set 3 | firminopolis
# Processing Record 34 of Set 3 | zhanatas
# City not found. Skipping...
# Processing Record 35 of Set 3 | balezino
# Processing Record 36 of Set 3 | sabla
# Processing Record 37 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 38 of Set 3 | bluff
# Processing Record 39 of Set 3 | fortuna
# Processing Record 40 of Set 3 | college
# Processing Record 41 of Set 3 | inhambane
# Processing Record 42 of Set 3 | rawlins
# Processing Record 43 of Set 3 | labuhan
# Processing Record 44 of Set 3 | yarim
# Processing Record 45 of Set 3 | naze
# Processing Record 46 of Set 3 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 47 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 48 of Set 3 | vinh
# Processing Record 49 of Set 3 | komsomolskiy
# Processing Record 50 of Set 3 | atambua
# Processing Record 1 of Set 4 | deputatskiy
# Processing Record 2 of Set 4 | salinopolis
# Processing Record 3 of Set 4 | ancud
# Processing Record 4 of Set 4 | tuatapere
# Processing Record 5 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 6 of Set 4 | bengkulu
# Processing Record 7 of Set 4 | hammerfest
# Processing Record 8 of Set 4 | pitimbu
# Processing Record 9 of Set 4 | pecos
# Processing Record 10 of Set 4 | homer
# Processing Record 11 of Set 4 | bogotol
# Processing Record 12 of Set 4 | fairbanks
# Processing Record 13 of Set 4 | sitborice
# Processing Record 14 of Set 4 | lompoc
# Processing Record 15 of Set 4 | leningradskiy
# Processing Record 16 of Set 4 | kavieng
# Processing Record 17 of Set 4 | clyde river
# Processing Record 18 of Set 4 | roi et
# Processing Record 19 of Set 4 | hamilton
# Processing Record 20 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 21 of Set 4 | pasni
# Processing Record 22 of Set 4 | saint-georges
# Processing Record 23 of Set 4 | charters towers
# Processing Record 24 of Set 4 | buala
# Processing Record 25 of Set 4 | yeppoon
# Processing Record 26 of Set 4 | buraydah
# Processing Record 27 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 28 of Set 4 | namatanai
# Processing Record 29 of Set 4 | maunabo
# Processing Record 30 of Set 4 | santa cruz
# Processing Record 31 of Set 4 | acapulco
# Processing Record 32 of Set 4 | bathsheba
# Processing Record 33 of Set 4 | barra
# Processing Record 34 of Set 4 | narsaq
# Processing Record 35 of Set 4 | hobart
# Processing Record 36 of Set 4 | roma
# Processing Record 37 of Set 4 | kaitangata
# Processing Record 38 of Set 4 | tyup
# Processing Record 39 of Set 4 | baykit
# Processing Record 40 of Set 4 | pineto
# Processing Record 41 of Set 4 | lima
# Processing Record 42 of Set 4 | burnie
# Processing Record 43 of Set 4 | conde
# Processing Record 44 of Set 4 | tasiilaq
# Processing Record 45 of Set 4 | novyy urgal
# Processing Record 46 of Set 4 | lincoln
# Processing Record 47 of Set 4 | shingu
# Processing Record 48 of Set 4 | coihaique
# Processing Record 49 of Set 4 | tovuz
# Processing Record 50 of Set 4 | coquimbo
# Processing Record 1 of Set 5 | natchez
# Processing Record 2 of Set 5 | podgornoye
# Processing Record 3 of Set 5 | pelym
# Processing Record 4 of Set 5 | bombo
# Processing Record 5 of Set 5 | santiago de cao
# Processing Record 6 of Set 5 | lavrentiya
# Processing Record 7 of Set 5 | daru
# Processing Record 8 of Set 5 | kuruman
# Processing Record 9 of Set 5 | riyadh
# Processing Record 10 of Set 5 | praia
# Processing Record 11 of Set 5 | port arthur
# Processing Record 12 of Set 5 | riyaq
# City not found. Skipping...
# Processing Record 13 of Set 5 | san juan
# Processing Record 14 of Set 5 | fresno
# Processing Record 15 of Set 5 | richards bay
# Processing Record 16 of Set 5 | dudinka
# Processing Record 17 of Set 5 | gat
# Processing Record 18 of Set 5 | bethel
# Processing Record 19 of Set 5 | husavik
# Processing Record 20 of Set 5 | mormugao
# Processing Record 21 of Set 5 | luwuk
# Processing Record 22 of Set 5 | port shepstone
# Processing Record 23 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 24 of Set 5 | victoria
# Processing Record 25 of Set 5 | nanortalik
# Processing Record 26 of Set 5 | oyama
# Processing Record 27 of Set 5 | helvecia
# Processing Record 28 of Set 5 | cagayan de tawi-tawi
# City not found. Skipping...
# Processing Record 29 of Set 5 | poso
# Processing Record 30 of Set 5 | bom jesus
# Processing Record 31 of Set 5 | montepuez
# Processing Record 32 of Set 5 | katsuura
# Processing Record 33 of Set 5 | prainha
# Processing Record 34 of Set 5 | jinan
# Processing Record 35 of Set 5 | guangyuan
# Processing Record 36 of Set 5 | maragogi
# Processing Record 37 of Set 5 | port-gentil
# Processing Record 38 of Set 5 | karaton
# Processing Record 39 of Set 5 | bubaque
# Processing Record 40 of Set 5 | mahebourg
# Processing Record 41 of Set 5 | cabangahan
# Processing Record 42 of Set 5 | barentu
# Processing Record 43 of Set 5 | hambantota
# Processing Record 44 of Set 5 | airai
# Processing Record 45 of Set 5 | omboue
# Processing Record 46 of Set 5 | seoul
# Processing Record 47 of Set 5 | hilo
# Processing Record 48 of Set 5 | mapimi
# Processing Record 49 of Set 5 | dharmanagar
# Processing Record 50 of Set 5 | candawaga
# City not found. Skipping...
# Processing Record 1 of Set 6 | baghdad
# Processing Record 2 of Set 6 | bobo dioulasso
# Processing Record 3 of Set 6 | touros
# Processing Record 4 of Set 6 | vila velha
# Processing Record 5 of Set 6 | nuuk
# Processing Record 6 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 7 of Set 6 | manokwari
# Processing Record 8 of Set 6 | saint-francois
# Processing Record 9 of Set 6 | jarvenpaa
# Processing Record 10 of Set 6 | wiwili
# Processing Record 11 of Set 6 | tuktoyaktuk
# Processing Record 12 of Set 6 | sibolga
# Processing Record 13 of Set 6 | khairpur
# Processing Record 14 of Set 6 | somerset east
# Processing Record 15 of Set 6 | dikson
# Processing Record 16 of Set 6 | chokurdakh
# Processing Record 17 of Set 6 | upernavik
# Processing Record 18 of Set 6 | sorland
# Processing Record 19 of Set 6 | martil
# Processing Record 20 of Set 6 | wichian buri
# Processing Record 21 of Set 6 | macau
# Processing Record 22 of Set 6 | port hedland
# Processing Record 23 of Set 6 | longyearbyen
# Processing Record 24 of Set 6 | mmathubudukwane
# Processing Record 25 of Set 6 | pasighat
# Processing Record 26 of Set 6 | meridian
# Processing Record 27 of Set 6 | manacapuru
# Processing Record 28 of Set 6 | havre-saint-pierre
# Processing Record 29 of Set 6 | mokhsogollokh
# Processing Record 30 of Set 6 | mopipi
# Processing Record 31 of Set 6 | port augusta
# Processing Record 32 of Set 6 | san cristobal
# Processing Record 33 of Set 6 | valle nacional
# Processing Record 34 of Set 6 | kaeo
# Processing Record 35 of Set 6 | mana
# Processing Record 36 of Set 6 | beringovskiy
# Processing Record 37 of Set 6 | bushenyi
# Processing Record 38 of Set 6 | rio gallegos
# Processing Record 39 of Set 6 | ingham
# Processing Record 40 of Set 6 | nsukka
# Processing Record 41 of Set 6 | elmadag
# Processing Record 42 of Set 6 | tilichiki
# Processing Record 43 of Set 6 | faanui
# Processing Record 44 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 45 of Set 6 | garachine
# Processing Record 46 of Set 6 | milkovo
# Processing Record 47 of Set 6 | souillac
# Processing Record 48 of Set 6 | namie
# Processing Record 49 of Set 6 | duma
# Processing Record 50 of Set 6 | inta
# Processing Record 1 of Set 7 | meadow lake
# Processing Record 2 of Set 7 | chara
# Processing Record 3 of Set 7 | alofi
# Processing Record 4 of Set 7 | bardiyah
# Processing Record 5 of Set 7 | tehachapi
# Processing Record 6 of Set 7 | bam
# Processing Record 7 of Set 7 | klaksvik
# Processing Record 8 of Set 7 | kirovskiy
# Processing Record 9 of Set 7 | sena madureira
# Processing Record 10 of Set 7 | berbera
# Processing Record 11 of Set 7 | verkhoyansk
# Processing Record 12 of Set 7 | faya
# Processing Record 13 of Set 7 | leh
# Processing Record 14 of Set 7 | farafangana
# Processing Record 15 of Set 7 | bagan
# Processing Record 16 of Set 7 | dharmadam
# Processing Record 17 of Set 7 | abalak
# Processing Record 18 of Set 7 | rivera
# Processing Record 19 of Set 7 | umm lajj
# Processing Record 20 of Set 7 | tutoia
# Processing Record 21 of Set 7 | vila
# Processing Record 22 of Set 7 | ambulu
# Processing Record 23 of Set 7 | kupang
# Processing Record 24 of Set 7 | baherden
# Processing Record 25 of Set 7 | cockburn town
# Processing Record 26 of Set 7 | ponta delgada
# Processing Record 27 of Set 7 | lagoa
# Processing Record 28 of Set 7 | maceio
# Processing Record 29 of Set 7 | traian
# Processing Record 30 of Set 7 | port hardy
# Processing Record 31 of Set 7 | yacuiba
# Processing Record 32 of Set 7 | rio verde de mato grosso
# Processing Record 33 of Set 7 | pathein
# Processing Record 34 of Set 7 | broome
# Processing Record 35 of Set 7 | penzance
# Processing Record 36 of Set 7 | ulaanbaatar
# Processing Record 37 of Set 7 | eunice
# Processing Record 38 of Set 7 | ippy
# Processing Record 39 of Set 7 | opuwo
# Processing Record 40 of Set 7 | wagga wagga
# Processing Record 41 of Set 7 | obidos
# Processing Record 42 of Set 7 | shkotovo-26
# City not found. Skipping...
# Processing Record 43 of Set 7 | mahalapye
# Processing Record 44 of Set 7 | cumaribo
# City not found. Skipping...
# Processing Record 45 of Set 7 | kodiak
# Processing Record 46 of Set 7 | pemangkat
# Processing Record 47 of Set 7 | minot
# Processing Record 48 of Set 7 | berlevag
# Processing Record 49 of Set 7 | iqaluit
# Processing Record 50 of Set 7 | dale
# Processing Record 1 of Set 8 | san pedro
# Processing Record 2 of Set 8 | aklavik
# Processing Record 3 of Set 8 | singaraja
# Processing Record 4 of Set 8 | ovre ardal
# Processing Record 5 of Set 8 | gloversville
# Processing Record 6 of Set 8 | krasnoselkup
# Processing Record 7 of Set 8 | adrar
# Processing Record 8 of Set 8 | esperance
# Processing Record 9 of Set 8 | te anau
# Processing Record 10 of Set 8 | dawlatabad
# Processing Record 11 of Set 8 | pekan
# Processing Record 12 of Set 8 | omsukchan
# Processing Record 13 of Set 8 | yamada
# Processing Record 14 of Set 8 | masvingo
# Processing Record 15 of Set 8 | muisne
# Processing Record 16 of Set 8 | tahta
# Processing Record 17 of Set 8 | flinders
# Processing Record 18 of Set 8 | armacao dos buzios
# City not found. Skipping...
# Processing Record 19 of Set 8 | yining
# Processing Record 20 of Set 8 | tarata
# Processing Record 21 of Set 8 | fort nelson
# Processing Record 22 of Set 8 | tual
# Processing Record 23 of Set 8 | kegayli
# City not found. Skipping...
# Processing Record 24 of Set 8 | vestmannaeyjar
# Processing Record 25 of Set 8 | cherskiy
# Processing Record 26 of Set 8 | longlac
# City not found. Skipping...
# Processing Record 27 of Set 8 | zella-mehlis
# Processing Record 28 of Set 8 | sentyabrskiy
# City not found. Skipping...
# Processing Record 29 of Set 8 | vanavara
# Processing Record 30 of Set 8 | sechura
# Processing Record 31 of Set 8 | banda aceh
# Processing Record 32 of Set 8 | salalah
# Processing Record 33 of Set 8 | sorong
# Processing Record 34 of Set 8 | ushtobe
# Processing Record 35 of Set 8 | geraldton
# Processing Record 36 of Set 8 | aksarka
# Processing Record 37 of Set 8 | kieta
# Processing Record 38 of Set 8 | balkhash
# Processing Record 39 of Set 8 | muyezerskiy
# Processing Record 40 of Set 8 | mangrol
# Processing Record 41 of Set 8 | glenwood springs
# Processing Record 42 of Set 8 | ponta do sol
# Processing Record 43 of Set 8 | qasigiannguit
# Processing Record 44 of Set 8 | igrim
# Processing Record 45 of Set 8 | razdolnoye
# Processing Record 46 of Set 8 | goure
# Processing Record 47 of Set 8 | thunder bay
# Processing Record 48 of Set 8 | hauterive
# Processing Record 49 of Set 8 | santa ines
# Processing Record 50 of Set 8 | genthin
# Processing Record 1 of Set 9 | porto walter
# Processing Record 2 of Set 9 | conceicao do araguaia
# Processing Record 3 of Set 9 | avera
# Processing Record 4 of Set 9 | taoudenni
# Processing Record 5 of Set 9 | caravelas
# Processing Record 6 of Set 9 | otjimbingwe
# Processing Record 7 of Set 9 | lorengau
# Processing Record 8 of Set 9 | vangaindrano
# Processing Record 9 of Set 9 | abu dhabi
# Processing Record 10 of Set 9 | constitucion
# Processing Record 11 of Set 9 | kavaratti
# Processing Record 12 of Set 9 | ust-kulom
# Processing Record 13 of Set 9 | kamennogorsk
# Processing Record 14 of Set 9 | usinsk
# Processing Record 15 of Set 9 | falealupo
# City not found. Skipping...
# Processing Record 16 of Set 9 | azimur
# City not found. Skipping...
# Processing Record 17 of Set 9 | waycross
# Processing Record 18 of Set 9 | bahir dar
# Processing Record 19 of Set 9 | shimoda
# Processing Record 20 of Set 9 | valdivia
# Processing Record 21 of Set 9 | jahrom
# City not found. Skipping...
# Processing Record 22 of Set 9 | najran
# Processing Record 23 of Set 9 | prieska
# Processing Record 24 of Set 9 | belyy yar
# Processing Record 25 of Set 9 | buin
# Processing Record 26 of Set 9 | tecoanapa
# Processing Record 27 of Set 9 | takoradi
# Processing Record 28 of Set 9 | yankton
# Processing Record 29 of Set 9 | tucupita
# Processing Record 30 of Set 9 | santa cruz del sur
# Processing Record 31 of Set 9 | port macquarie
# Processing Record 32 of Set 9 | sobolevo
# Processing Record 33 of Set 9 | rocha
# Processing Record 34 of Set 9 | codrington
# Processing Record 35 of Set 9 | acari
# Processing Record 36 of Set 9 | san andres
# Processing Record 37 of Set 9 | atasu
# Processing Record 38 of Set 9 | mazamari
# Processing Record 39 of Set 9 | maltahohe
# Processing Record 40 of Set 9 | tungor
# Processing Record 41 of Set 9 | muroto
# Processing Record 42 of Set 9 | tamale
# Processing Record 43 of Set 9 | itoman
# Processing Record 44 of Set 9 | saldanha
# Processing Record 45 of Set 9 | izmit
# Processing Record 46 of Set 9 | palembang
# Processing Record 47 of Set 9 | tandil
# Processing Record 48 of Set 9 | cicuco
# Processing Record 49 of Set 9 | presidente medici
# Processing Record 50 of Set 9 | bambanglipuro
# Processing Record 1 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 2 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 3 of Set 10 | pingzhuang
# Processing Record 4 of Set 10 | baoqing
# Processing Record 5 of Set 10 | los llanos de aridane
# Processing Record 6 of Set 10 | tuni
# Processing Record 7 of Set 10 | altamira
# Processing Record 8 of Set 10 | pokaran
# Processing Record 9 of Set 10 | pevek
# Processing Record 10 of Set 10 | seddon
# Processing Record 11 of Set 10 | semirom
# Processing Record 12 of Set 10 | tarudant
# City not found. Skipping...
# Processing Record 13 of Set 10 | norfolk
# Processing Record 14 of Set 10 | pierre
# Processing Record 15 of Set 10 | lolua
# City not found. Skipping...
# Processing Record 16 of Set 10 | galgani
# City not found. Skipping...
# Processing Record 17 of Set 10 | kahului
# Processing Record 18 of Set 10 | puerto del rosario
# Processing Record 19 of Set 10 | pascagoula
# Processing Record 20 of Set 10 | oranjemund
# Processing Record 21 of Set 10 | raposa
# Processing Record 22 of Set 10 | poum
# Processing Record 23 of Set 10 | lata
# Processing Record 24 of Set 10 | biak
# Processing Record 25 of Set 10 | rio grande
# Processing Record 26 of Set 10 | sambava
# Processing Record 27 of Set 10 | bogorodskoye
# Processing Record 28 of Set 10 | kruisfontein
# Processing Record 29 of Set 10 | jumla
# Processing Record 30 of Set 10 | balikpapan
# Processing Record 31 of Set 10 | oranjestad
# Processing Record 32 of Set 10 | praia da vitoria
# Processing Record 33 of Set 10 | ous
# Processing Record 34 of Set 10 | grindavik
# Processing Record 35 of Set 10 | provost
# Processing Record 36 of Set 10 | lagunas
# Processing Record 37 of Set 10 | marakkanam
# Processing Record 38 of Set 10 | mahajanga
# Processing Record 39 of Set 10 | hervey bay
# Processing Record 40 of Set 10 | lake city
# Processing Record 41 of Set 10 | kilindoni
# Processing Record 42 of Set 10 | gumla
# Processing Record 43 of Set 10 | puerto leguizamo
# Processing Record 44 of Set 10 | alyangula
# Processing Record 45 of Set 10 | ilam
# Processing Record 46 of Set 10 | fare
# Processing Record 47 of Set 10 | raudeberg
# Processing Record 48 of Set 10 | mendahara
# City not found. Skipping...
# Processing Record 49 of Set 10 | chapada dos guimaraes
# Processing Record 50 of Set 10 | la gloria
# Processing Record 1 of Set 11 | ankazoabo
# Processing Record 2 of Set 11 | villa oliva
# City not found. Skipping...
# Processing Record 3 of Set 11 | marzuq
# Processing Record 4 of Set 11 | luganville
# Processing Record 5 of Set 11 | laguna
# Processing Record 6 of Set 11 | brae
# Processing Record 7 of Set 11 | port moresby
# Processing Record 8 of Set 11 | sao miguel do araguaia
# Processing Record 9 of Set 11 | tambun
# Processing Record 10 of Set 11 | ust-omchug
# Processing Record 11 of Set 11 | nemuro
# Processing Record 12 of Set 11 | tezu
# Processing Record 13 of Set 11 | cabra
# Processing Record 14 of Set 11 | chihuahua
# Processing Record 15 of Set 11 | tungkang
# City not found. Skipping...
# Processing Record 16 of Set 11 | la rioja
# Processing Record 17 of Set 11 | hofn
# Processing Record 18 of Set 11 | lasa
# Processing Record 19 of Set 11 | rungata
# City not found. Skipping...
# Processing Record 20 of Set 11 | muros
# Processing Record 21 of Set 11 | khani
# Processing Record 22 of Set 11 | chapais
# Processing Record 23 of Set 11 | hami
# Processing Record 24 of Set 11 | lienz
# Processing Record 25 of Set 11 | marsh harbour
# Processing Record 26 of Set 11 | beisfjord
# Processing Record 27 of Set 11 | tessalit
# Processing Record 28 of Set 11 | luderitz
# Processing Record 29 of Set 11 | topolobampo
# Processing Record 30 of Set 11 | cobija
# Processing Record 31 of Set 11 | rubtsovsk
# Processing Record 32 of Set 11 | astana
# Processing Record 33 of Set 11 | yerbogachen
# Processing Record 34 of Set 11 | bria
# Processing Record 35 of Set 11 | lubango
# Processing Record 36 of Set 11 | caraballeda
# Processing Record 37 of Set 11 | mandera
# Processing Record 38 of Set 11 | biloela
# Processing Record 39 of Set 11 | krivosheino
# Processing Record 40 of Set 11 | wuzhou
# Processing Record 41 of Set 11 | mabaruma
# Processing Record 42 of Set 11 | north battleford
# Processing Record 43 of Set 11 | roebourne
# Processing Record 44 of Set 11 | konya
# Processing Record 45 of Set 11 | nantong
# Processing Record 46 of Set 11 | zyryanka
# Processing Record 47 of Set 11 | zwedru
# Processing Record 48 of Set 11 | brigantine
# Processing Record 49 of Set 11 | baramati
# Processing Record 50 of Set 11 | ilulissat
# Processing Record 1 of Set 12 | himora
# City not found. Skipping...
# Processing Record 2 of Set 12 | le port
# Processing Record 3 of Set 12 | talesh
# City not found. Skipping...
# Processing Record 4 of Set 12 | tura
# Processing Record 5 of Set 12 | acajutla
# Processing Record 6 of Set 12 | karaul
# City not found. Skipping...
# Processing Record 7 of Set 12 | chivay
# Processing Record 8 of Set 12 | bosaso
# Processing Record 9 of Set 12 | broken hill
# Processing Record 10 of Set 12 | waw
# Processing Record 11 of Set 12 | dipkarpaz
# City not found. Skipping...
# Processing Record 12 of Set 12 | vlasinesti
# Processing Record 13 of Set 12 | uyovu
# Processing Record 14 of Set 12 | tooele
# Processing Record 15 of Set 12 | namibe
# Processing Record 16 of Set 12 | san patricio
# Processing Record 17 of Set 12 | high level
# Processing Record 18 of Set 12 | togur
# Processing Record 19 of Set 12 | elizabethton
# Processing Record 20 of Set 12 | orlik
# Processing Record 21 of Set 12 | tottori
# Processing Record 22 of Set 12 | camapua
# Processing Record 23 of Set 12 | stranda
# Processing Record 24 of Set 12 | oreanda
# City not found. Skipping...
# Processing Record 25 of Set 12 | sao raimundo das mangabeiras
# Processing Record 26 of Set 12 | margate
# Processing Record 27 of Set 12 | rundu
# Processing Record 28 of Set 12 | marfino
# Processing Record 29 of Set 12 | bongandanga
# Processing Record 30 of Set 12 | paradwip
# City not found. Skipping...
# Processing Record 31 of Set 12 | visby
# Processing Record 32 of Set 12 | zunyi
# Processing Record 33 of Set 12 | mandan
# Processing Record 34 of Set 12 | kulhudhuffushi
# Processing Record 35 of Set 12 | temaraia
# City not found. Skipping...
# Processing Record 36 of Set 12 | roura
# Processing Record 37 of Set 12 | arica
# Processing Record 38 of Set 12 | ardakan
# Processing Record 39 of Set 12 | lodwar
# Processing Record 40 of Set 12 | toliary
# City not found. Skipping...
# Processing Record 41 of Set 12 | maralal
# Processing Record 42 of Set 12 | san quintin
# Processing Record 43 of Set 12 | yar-sale
# Processing Record 44 of Set 12 | sayansk
# Processing Record 45 of Set 12 | iaciara
# Processing Record 46 of Set 12 | freeport
# Processing Record 47 of Set 12 | maghama
# City not found. Skipping...
# Processing Record 48 of Set 12 | barawe
# City not found. Skipping...
# Processing Record 49 of Set 12 | kundiawa
# Processing Record 50 of Set 12 | cidreira
# Processing Record 1 of Set 13 | bumba
# Processing Record 2 of Set 13 | awjilah
# Processing Record 3 of Set 13 | midleton
# Processing Record 4 of Set 13 | sao jose da coroa grande
# Processing Record 5 of Set 13 | xining
# Processing Record 6 of Set 13 | odweyne
# Processing Record 7 of Set 13 | bandarbeyla
# Processing Record 8 of Set 13 | bonthe
# Processing Record 9 of Set 13 | esfarayen
# Processing Record 10 of Set 13 | kysyl-syr
# Processing Record 11 of Set 13 | jardim
# Processing Record 12 of Set 13 | bandarban
# Processing Record 13 of Set 13 | bolungarvik
# City not found. Skipping...
# Processing Record 14 of Set 13 | chivilcoy
# Processing Record 15 of Set 13 | skelleftea
# Processing Record 16 of Set 13 | vila do maio
# Processing Record 17 of Set 13 | villa bruzual
# Processing Record 18 of Set 13 | magdagachi
# Processing Record 19 of Set 13 | krasnyy kholm
# Processing Record 20 of Set 13 | benesov nad ploucnici
# Processing Record 21 of Set 13 | zhigalovo
# Processing Record 22 of Set 13 | nouadhibou
# Processing Record 23 of Set 13 | vrangel
# Processing Record 24 of Set 13 | shihezi
# Processing Record 25 of Set 13 | nagaur
# Processing Record 26 of Set 13 | pakxe
# Processing Record 27 of Set 13 | mecca
# Processing Record 28 of Set 13 | dourbali
# Processing Record 29 of Set 13 | golden rock
# City not found. Skipping...
# Processing Record 30 of Set 13 | aflu
# City not found. Skipping...
# Processing Record 31 of Set 13 | batticaloa
# Processing Record 32 of Set 13 | evensk
# Processing Record 33 of Set 13 | mnogovershinnyy
# Processing Record 34 of Set 13 | dingle
# Processing Record 35 of Set 13 | tumannyy
# City not found. Skipping...
# Processing Record 36 of Set 13 | bairiki
# Processing Record 37 of Set 13 | oktyabrskoye
# Processing Record 38 of Set 13 | sassandra
# Processing Record 39 of Set 13 | bilma
# Processing Record 40 of Set 13 | viedma
# Processing Record 41 of Set 13 | vredendal
# Processing Record 42 of Set 13 | yueyang
# Processing Record 43 of Set 13 | ayan
# Processing Record 44 of Set 13 | babanusah
# City not found. Skipping...
# Processing Record 45 of Set 13 | pitmoaga
# Processing Record 46 of Set 13 | port keats
# Processing Record 47 of Set 13 | aras
# Processing Record 48 of Set 13 | liberal
# Processing Record 49 of Set 13 | aksu
# Processing Record 50 of Set 13 | yarovoye
# Processing Record 1 of Set 14 | srivardhan
# Processing Record 2 of Set 14 | bulgan
# Processing Record 3 of Set 14 | hobyo
# Processing Record 4 of Set 14 | gharo
# Processing Record 5 of Set 14 | manadhoo
# Processing Record 6 of Set 14 | tynaarlo
# Processing Record 7 of Set 14 | ubon ratchathani
# Processing Record 8 of Set 14 | palau
# Processing Record 9 of Set 14 | dukhovshchina
# Processing Record 10 of Set 14 | necochea
# Processing Record 11 of Set 14 | bintulu
# Processing Record 12 of Set 14 | inirida
# Processing Record 13 of Set 14 | rio blanco
# Processing Record 14 of Set 14 | korla
# Processing Record 15 of Set 14 | tautira
# Processing Record 16 of Set 14 | nata
# Processing Record 17 of Set 14 | elko
# Processing Record 18 of Set 14 | yatou
# Processing Record 19 of Set 14 | lai
# Processing Record 20 of Set 14 | luchegorsk
# Processing Record 21 of Set 14 | quatre cocos
# Processing Record 22 of Set 14 | guiren
# Processing Record 23 of Set 14 | utiroa
# City not found. Skipping...
# Processing Record 24 of Set 14 | talakan
# Processing Record 25 of Set 14 | mahibadhoo
# Processing Record 26 of Set 14 | malindi
# Processing Record 27 of Set 14 | cayenne
# Processing Record 28 of Set 14 | tuy hoa
# Processing Record 29 of Set 14 | esna
# Processing Record 30 of Set 14 | barcelos
# Processing Record 31 of Set 14 | yinchuan
# Processing Record 32 of Set 14 | praxedis guerrero
# Processing Record 33 of Set 14 | carsamba
# Processing Record 34 of Set 14 | praya
# Processing Record 35 of Set 14 | kargasok
# Processing Record 36 of Set 14 | houma
# Processing Record 37 of Set 14 | torbat-e jam
# Processing Record 38 of Set 14 | the valley
# Processing Record 39 of Set 14 | scottsbluff
# Processing Record 40 of Set 14 | atkinson
# Processing Record 41 of Set 14 | langsa
# Processing Record 42 of Set 14 | sao felix do xingu
# Processing Record 43 of Set 14 | kasane
# Processing Record 44 of Set 14 | vagur
# Processing Record 45 of Set 14 | lamar
# Processing Record 46 of Set 14 | lamesa
# Processing Record 47 of Set 14 | yantai
# Processing Record 48 of Set 14 | meulaboh
# Processing Record 49 of Set 14 | holme
# Processing Record 50 of Set 14 | jacareacanga
# Processing Record 1 of Set 15 | humenne
# Processing Record 2 of Set 15 | sawankhalok
# Processing Record 3 of Set 15 | alta floresta
# Processing Record 4 of Set 15 | okha
# Processing Record 5 of Set 15 | paris
# Processing Record 6 of Set 15 | pindi bhattian
# Processing Record 7 of Set 15 | harper
# Processing Record 8 of Set 15 | pringsewu
# Processing Record 9 of Set 15 | maningrida
# Processing Record 10 of Set 15 | alice springs
# Processing Record 11 of Set 15 | guider
# Processing Record 12 of Set 15 | ostrovnoy
# Processing Record 13 of Set 15 | along
# Processing Record 14 of Set 15 | sembabule
# Processing Record 15 of Set 15 | zapolyarnyy
# Processing Record 16 of Set 15 | chivacoa
# Processing Record 17 of Set 15 | leirvik
# Processing Record 18 of Set 15 | bartow
# Processing Record 19 of Set 15 | sao joao da barra
# Processing Record 20 of Set 15 | okhotsk
# Processing Record 21 of Set 15 | ulaangom
# Processing Record 22 of Set 15 | sioux lookout
# Processing Record 23 of Set 15 | scicli
# Processing Record 24 of Set 15 | anchorage
# Processing Record 25 of Set 15 | cheuskiny
# City not found. Skipping...
# Processing Record 26 of Set 15 | sayyan
# Processing Record 27 of Set 15 | moose factory
# Processing Record 28 of Set 15 | ahuimanu
# Processing Record 29 of Set 15 | kirakira
# Processing Record 30 of Set 15 | karpogory
# Processing Record 31 of Set 15 | waipawa
# Processing Record 32 of Set 15 | tiznit
# Processing Record 33 of Set 15 | ampanihy
# Processing Record 34 of Set 15 | tromso
# Processing Record 35 of Set 15 | visnes
# Processing Record 36 of Set 15 | salta
# Processing Record 37 of Set 15 | mackay
# Processing Record 38 of Set 15 | yulara
# Processing Record 39 of Set 15 | kaseda
# Processing Record 40 of Set 15 | vung tau
# Processing Record 41 of Set 15 | carballo
# Processing Record 42 of Set 15 | ust-nera
# Processing Record 43 of Set 15 | lagunillas
# Processing Record 44 of Set 15 | coahuayana
# Processing Record 45 of Set 15 | kasama
# Processing Record 46 of Set 15 | sinnamary
# Processing Record 47 of Set 15 | camacha
# Processing Record 48 of Set 15 | paamiut
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_weather = requests.get(city_url).json()
like print(city_weather)
# Out:
#   File "<ipython-input-11-7680ff1fbf66>", line 2
#     like print(city_weather)
#              ^
# SyntaxError: invalid syntax
