# %%
# Begin the Challenge 6
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 778

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=b59a0f248a67ea7f00c6fbe29a1eb479"
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=b59a0f248a67ea7f00c6fbe29a1eb479&q=Boston

# %%
# Create an endpoint URL for a city.
city_url = url + "&q=" + "Boston"
city_weather = requests.get(city_url)
city_weather.json()
# Out:
# {'coord': {'lon': -71.0598, 'lat': 42.3584},
#  'weather': [{'id': 802,
#    'main': 'Clouds',
#    'description': 'scattered clouds',
#    'icon': '03d'}],
#  'base': 'stations',
#  'main': {'temp': 86.29,
#   'feels_like': 87.48,
#   'temp_min': 80.94,
#   'temp_max': 90.61,
#   'pressure': 1009,
#   'humidity': 47},
#  'visibility': 10000,
#  'wind': {'speed': 10, 'deg': 284, 'gust': 20},
#  'clouds': {'all': 40},
#  'dt': 1622910515,
#  'sys': {'type': 2,
#   'id': 2013408,
#   'country': 'US',
#   'sunrise': 1622884109,
#   'sunset': 1622938644},
#  'timezone': -14400,
#  'id': 4930956,
#  'name': 'Boston',
#  'cod': 200}

# %%
# 6.2.6 using the imports from above start on getting list of cities in groups of 50

# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_weather_desc = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        # city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_weather_desc})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hasaki
# Processing Record 2 of Set 1 | carnarvon
# Processing Record 3 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 4 of Set 1 | hamilton
# Processing Record 5 of Set 1 | faanui
# Processing Record 6 of Set 1 | hermanus
# Processing Record 7 of Set 1 | codrington
# Processing Record 8 of Set 1 | vaini
# Processing Record 9 of Set 1 | port alfred
# Processing Record 10 of Set 1 | tuktoyaktuk
# Processing Record 11 of Set 1 | jamestown
# Processing Record 12 of Set 1 | ushuaia
# Processing Record 13 of Set 1 | paraiso
# Processing Record 14 of Set 1 | kaitangata
# Processing Record 15 of Set 1 | sinnamary
# Processing Record 16 of Set 1 | derzhavinsk
# Processing Record 17 of Set 1 | berdigestyakh
# Processing Record 18 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 19 of Set 1 | albany
# Processing Record 20 of Set 1 | punta arenas
# Processing Record 21 of Set 1 | saint-pierre
# Processing Record 22 of Set 1 | cape town
# Processing Record 23 of Set 1 | avarua
# Processing Record 24 of Set 1 | cidreira
# Processing Record 25 of Set 1 | broome
# Processing Record 26 of Set 1 | hobart
# Processing Record 27 of Set 1 | gizo
# Processing Record 28 of Set 1 | vardo
# Processing Record 29 of Set 1 | chuy
# Processing Record 30 of Set 1 | ano mera
# Processing Record 31 of Set 1 | busselton
# Processing Record 32 of Set 1 | nanortalik
# Processing Record 33 of Set 1 | gat
# Processing Record 34 of Set 1 | longyearbyen
# Processing Record 35 of Set 1 | fortuna
# Processing Record 36 of Set 1 | chokurdakh
# Processing Record 37 of Set 1 | vila franca do campo
# Processing Record 38 of Set 1 | atuona
# Processing Record 39 of Set 1 | saint george
# Processing Record 40 of Set 1 | baghdad
# Processing Record 41 of Set 1 | benghazi
# Processing Record 42 of Set 1 | hilo
# Processing Record 43 of Set 1 | itarema
# Processing Record 44 of Set 1 | egvekinot
# Processing Record 45 of Set 1 | divnogorsk
# Processing Record 46 of Set 1 | thompson
# Processing Record 47 of Set 1 | bethel
# Processing Record 48 of Set 1 | bengkulu
# Processing Record 49 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 50 of Set 1 | rikitea
# Processing Record 1 of Set 2 | borzna
# Processing Record 2 of Set 2 | cabo san lucas
# Processing Record 3 of Set 2 | yalchiki
# City not found. Skipping...
# Processing Record 4 of Set 2 | ugep
# Processing Record 5 of Set 2 | barcelos
# Processing Record 6 of Set 2 | nikolskoye
# Processing Record 7 of Set 2 | bluff
# Processing Record 8 of Set 2 | mataura
# Processing Record 9 of Set 2 | hithadhoo
# Processing Record 10 of Set 2 | colares
# Processing Record 11 of Set 2 | almeria
# Processing Record 12 of Set 2 | taltal
# Processing Record 13 of Set 2 | fairview
# Processing Record 14 of Set 2 | bayir
# Processing Record 15 of Set 2 | arraial do cabo
# Processing Record 16 of Set 2 | mirabad
# Processing Record 17 of Set 2 | mamakan
# Processing Record 18 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 19 of Set 2 | zhanaozen
# Processing Record 20 of Set 2 | namibe
# Processing Record 21 of Set 2 | sabha
# Processing Record 22 of Set 2 | east london
# Processing Record 23 of Set 2 | ponta do sol
# Processing Record 24 of Set 2 | puerto ayora
# Processing Record 25 of Set 2 | jinchang
# Processing Record 26 of Set 2 | totness
# Processing Record 27 of Set 2 | pisco
# Processing Record 28 of Set 2 | new norfolk
# Processing Record 29 of Set 2 | dhankuta
# Processing Record 30 of Set 2 | morgan city
# Processing Record 31 of Set 2 | butaritari
# Processing Record 32 of Set 2 | pitkyaranta
# Processing Record 33 of Set 2 | mildura
# Processing Record 34 of Set 2 | victoria
# Processing Record 35 of Set 2 | nelson bay
# Processing Record 36 of Set 2 | kodiak
# Processing Record 37 of Set 2 | diamantino
# Processing Record 38 of Set 2 | wankaner
# Processing Record 39 of Set 2 | usinsk
# Processing Record 40 of Set 2 | chapais
# Processing Record 41 of Set 2 | korla
# Processing Record 42 of Set 2 | erenhot
# Processing Record 43 of Set 2 | samarai
# Processing Record 44 of Set 2 | kavaratti
# Processing Record 45 of Set 2 | saskylakh
# Processing Record 46 of Set 2 | saint-philippe
# Processing Record 47 of Set 2 | barreiro
# Processing Record 48 of Set 2 | sao felix do xingu
# Processing Record 49 of Set 2 | dinsor
# City not found. Skipping...
# Processing Record 50 of Set 2 | norman wells
# Processing Record 1 of Set 3 | uusikaupunki
# Processing Record 2 of Set 3 | bredasdorp
# Processing Record 3 of Set 3 | cascais
# Processing Record 4 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 5 of Set 3 | gornozavodsk
# Processing Record 6 of Set 3 | kavieng
# Processing Record 7 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 8 of Set 3 | darab
# Processing Record 9 of Set 3 | tazovskiy
# Processing Record 10 of Set 3 | maniitsoq
# Processing Record 11 of Set 3 | uvira
# Processing Record 12 of Set 3 | atar
# Processing Record 13 of Set 3 | kasongo-lunda
# Processing Record 14 of Set 3 | souillac
# Processing Record 15 of Set 3 | hajipur
# Processing Record 16 of Set 3 | kamaishi
# Processing Record 17 of Set 3 | bathsheba
# Processing Record 18 of Set 3 | port elizabeth
# Processing Record 19 of Set 3 | aklavik
# Processing Record 20 of Set 3 | roald
# Processing Record 21 of Set 3 | yakima
# Processing Record 22 of Set 3 | port hedland
# Processing Record 23 of Set 3 | esperance
# Processing Record 24 of Set 3 | kasongo
# Processing Record 25 of Set 3 | mpanda
# Processing Record 26 of Set 3 | padang
# Processing Record 27 of Set 3 | glens falls
# Processing Record 28 of Set 3 | san patricio
# Processing Record 29 of Set 3 | deputatskiy
# Processing Record 30 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 31 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 32 of Set 3 | guerrero negro
# Processing Record 33 of Set 3 | castro
# Processing Record 34 of Set 3 | pinega
# Processing Record 35 of Set 3 | acarau
# Processing Record 36 of Set 3 | ribeira grande
# Processing Record 37 of Set 3 | upernavik
# Processing Record 38 of Set 3 | urengoy
# Processing Record 39 of Set 3 | ormara
# Processing Record 40 of Set 3 | joao pinheiro
# Processing Record 41 of Set 3 | chuguyevka
# Processing Record 42 of Set 3 | tefe
# Processing Record 43 of Set 3 | kaihua
# Processing Record 44 of Set 3 | suratgarh
# Processing Record 45 of Set 3 | bintawan
# Processing Record 46 of Set 3 | bulgan
# Processing Record 47 of Set 3 | khatanga
# Processing Record 48 of Set 3 | bambous virieux
# Processing Record 49 of Set 3 | lahat
# Processing Record 50 of Set 3 | abay
# Processing Record 1 of Set 4 | mae sot
# Processing Record 2 of Set 4 | asau
# Processing Record 3 of Set 4 | linkoping
# Processing Record 4 of Set 4 | inhambane
# Processing Record 5 of Set 4 | banda aceh
# Processing Record 6 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 7 of Set 4 | katsuura
# Processing Record 8 of Set 4 | masterton
# Processing Record 9 of Set 4 | maceio
# Processing Record 10 of Set 4 | paita
# Processing Record 11 of Set 4 | ayan
# Processing Record 12 of Set 4 | kupang
# Processing Record 13 of Set 4 | tanjong karang
# City not found. Skipping...
# Processing Record 14 of Set 4 | longlac
# City not found. Skipping...
# Processing Record 15 of Set 4 | kazuno
# Processing Record 16 of Set 4 | mathathane
# Processing Record 17 of Set 4 | qaanaaq
# Processing Record 18 of Set 4 | olean
# Processing Record 19 of Set 4 | bargal
# City not found. Skipping...
# Processing Record 20 of Set 4 | rawson
# Processing Record 21 of Set 4 | severo-kurilsk
# Processing Record 22 of Set 4 | marawi
# Processing Record 23 of Set 4 | yaizu
# Processing Record 24 of Set 4 | malwan
# City not found. Skipping...
# Processing Record 25 of Set 4 | bandarbeyla
# Processing Record 26 of Set 4 | geraldton
# Processing Record 27 of Set 4 | hami
# Processing Record 28 of Set 4 | westport
# Processing Record 29 of Set 4 | klaksvik
# Processing Record 30 of Set 4 | copiapo
# Processing Record 31 of Set 4 | abu kamal
# Processing Record 32 of Set 4 | jinxiang
# Processing Record 33 of Set 4 | barra patuca
# Processing Record 34 of Set 4 | lebu
# Processing Record 35 of Set 4 | awjilah
# Processing Record 36 of Set 4 | samalaeulu
# City not found. Skipping...
# Processing Record 37 of Set 4 | tommot
# Processing Record 38 of Set 4 | mahebourg
# Processing Record 39 of Set 4 | puerto penasco
# Processing Record 40 of Set 4 | ugoofaaru
# Processing Record 41 of Set 4 | cherskiy
# Processing Record 42 of Set 4 | bowral
# Processing Record 43 of Set 4 | falmouth
# Processing Record 44 of Set 4 | port-gentil
# Processing Record 45 of Set 4 | saryagash
# Processing Record 46 of Set 4 | madang
# Processing Record 47 of Set 4 | le vauclin
# Processing Record 48 of Set 4 | iqaluit
# Processing Record 49 of Set 4 | vestmannaeyjar
# Processing Record 50 of Set 4 | tibasosa
# Processing Record 1 of Set 5 | sumbawa
# City not found. Skipping...
# Processing Record 2 of Set 5 | mancio lima
# Processing Record 3 of Set 5 | rovaniemi
# Processing Record 4 of Set 5 | waipawa
# Processing Record 5 of Set 5 | tabou
# Processing Record 6 of Set 5 | waingapu
# Processing Record 7 of Set 5 | dikson
# Processing Record 8 of Set 5 | tiksi
# Processing Record 9 of Set 5 | gornopravdinsk
# Processing Record 10 of Set 5 | chimore
# Processing Record 11 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 12 of Set 5 | yantal
# Processing Record 13 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 14 of Set 5 | mar del plata
# Processing Record 15 of Set 5 | tuggurt
# City not found. Skipping...
# Processing Record 16 of Set 5 | shimoda
# Processing Record 17 of Set 5 | dunedin
# Processing Record 18 of Set 5 | quatre cocos
# Processing Record 19 of Set 5 | ammon
# Processing Record 20 of Set 5 | korisos
# Processing Record 21 of Set 5 | garowe
# Processing Record 22 of Set 5 | wajima
# Processing Record 23 of Set 5 | lexington
# Processing Record 24 of Set 5 | sao joao da barra
# Processing Record 25 of Set 5 | omboue
# Processing Record 26 of Set 5 | ampanihy
# Processing Record 27 of Set 5 | kahului
# Processing Record 28 of Set 5 | cimislia
# Processing Record 29 of Set 5 | gravdal
# Processing Record 30 of Set 5 | ashland
# Processing Record 31 of Set 5 | kruisfontein
# Processing Record 32 of Set 5 | aksu
# Processing Record 33 of Set 5 | warman
# Processing Record 34 of Set 5 | saldanha
# Processing Record 35 of Set 5 | gamba
# Processing Record 36 of Set 5 | palampur
# Processing Record 37 of Set 5 | tasiilaq
# Processing Record 38 of Set 5 | pyinmana
# Processing Record 39 of Set 5 | kuala lipis
# Processing Record 40 of Set 5 | mosquera
# Processing Record 41 of Set 5 | airai
# Processing Record 42 of Set 5 | vanavara
# Processing Record 43 of Set 5 | pevek
# Processing Record 44 of Set 5 | beyneu
# Processing Record 45 of Set 5 | vila
# Processing Record 46 of Set 5 | manaure
# Processing Record 47 of Set 5 | kapaa
# Processing Record 48 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 49 of Set 5 | ust-ishim
# Processing Record 50 of Set 5 | florida
# Processing Record 1 of Set 6 | georgetown
# Processing Record 2 of Set 6 | vila velha
# Processing Record 3 of Set 6 | rundu
# Processing Record 4 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 5 of Set 6 | brae
# Processing Record 6 of Set 6 | kawana waters
# City not found. Skipping...
# Processing Record 7 of Set 6 | pineville
# Processing Record 8 of Set 6 | najran
# Processing Record 9 of Set 6 | ozernovskiy
# Processing Record 10 of Set 6 | coihaique
# Processing Record 11 of Set 6 | poretskoye
# Processing Record 12 of Set 6 | bandarban
# Processing Record 13 of Set 6 | te anau
# Processing Record 14 of Set 6 | owando
# Processing Record 15 of Set 6 | bodden town
# Processing Record 16 of Set 6 | lata
# Processing Record 17 of Set 6 | mount gambier
# Processing Record 18 of Set 6 | vostok
# Processing Record 19 of Set 6 | saint-joseph
# Processing Record 20 of Set 6 | puerto narino
# Processing Record 21 of Set 6 | torphins
# Processing Record 22 of Set 6 | karonga
# Processing Record 23 of Set 6 | palu
# Processing Record 24 of Set 6 | berlevag
# Processing Record 25 of Set 6 | nome
# Processing Record 26 of Set 6 | faya
# Processing Record 27 of Set 6 | dzaoudzi
# Processing Record 28 of Set 6 | kieta
# Processing Record 29 of Set 6 | khash
# Processing Record 30 of Set 6 | stornoway
# Processing Record 31 of Set 6 | khirkiya
# Processing Record 32 of Set 6 | batagay-alyta
# Processing Record 33 of Set 6 | beloha
# Processing Record 34 of Set 6 | tura
# Processing Record 35 of Set 6 | agadez
# Processing Record 36 of Set 6 | moskhokhorion
# City not found. Skipping...
# Processing Record 37 of Set 6 | liepaja
# Processing Record 38 of Set 6 | avera
# Processing Record 39 of Set 6 | kilindoni
# Processing Record 40 of Set 6 | ewa beach
# Processing Record 41 of Set 6 | kurumkan
# Processing Record 42 of Set 6 | barrow
# Processing Record 43 of Set 6 | venice
# Processing Record 44 of Set 6 | cabedelo
# Processing Record 45 of Set 6 | saint-augustin
# Processing Record 46 of Set 6 | hambantota
# Processing Record 47 of Set 6 | olinda
# Processing Record 48 of Set 6 | alamos
# Processing Record 49 of Set 6 | lolua
# City not found. Skipping...
# Processing Record 50 of Set 6 | parfino
# Processing Record 1 of Set 7 | saint anthony
# Processing Record 2 of Set 7 | sarkikaraagac
# Processing Record 3 of Set 7 | olafsvik
# Processing Record 4 of Set 7 | ilulissat
# Processing Record 5 of Set 7 | narsaq
# Processing Record 6 of Set 7 | lagos
# Processing Record 7 of Set 7 | dwarka
# Processing Record 8 of Set 7 | alofi
# Processing Record 9 of Set 7 | devyatka
# City not found. Skipping...
# Processing Record 10 of Set 7 | kysyl-syr
# Processing Record 11 of Set 7 | kamenskoye
# City not found. Skipping...
# Processing Record 12 of Set 7 | kiruna
# Processing Record 13 of Set 7 | sitka
# Processing Record 14 of Set 7 | mandan
# Processing Record 15 of Set 7 | yarada
# Processing Record 16 of Set 7 | port-cartier
# Processing Record 17 of Set 7 | barentsburg
# City not found. Skipping...
# Processing Record 18 of Set 7 | mocuba
# Processing Record 19 of Set 7 | oliveira dos brejinhos
# Processing Record 20 of Set 7 | jasper
# Processing Record 21 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 22 of Set 7 | pangoa
# Processing Record 23 of Set 7 | ancud
# Processing Record 24 of Set 7 | rocha
# Processing Record 25 of Set 7 | masuda
# Processing Record 26 of Set 7 | yellowknife
# Processing Record 27 of Set 7 | marovoay
# Processing Record 28 of Set 7 | eureka
# Processing Record 29 of Set 7 | mount isa
# Processing Record 30 of Set 7 | college
# Processing Record 31 of Set 7 | luwuk
# Processing Record 32 of Set 7 | balkanabat
# Processing Record 33 of Set 7 | sorvag
# City not found. Skipping...
# Processing Record 34 of Set 7 | moerai
# Processing Record 35 of Set 7 | yuancheng
# Processing Record 36 of Set 7 | poum
# Processing Record 37 of Set 7 | gurdaspur
# City not found. Skipping...
# Processing Record 38 of Set 7 | champerico
# Processing Record 39 of Set 7 | guatire
# Processing Record 40 of Set 7 | izazi
# Processing Record 41 of Set 7 | paramonga
# Processing Record 42 of Set 7 | kastamonu
# Processing Record 43 of Set 7 | bonavista
# Processing Record 44 of Set 7 | neiafu
# Processing Record 45 of Set 7 | sur
# Processing Record 46 of Set 7 | depew
# Processing Record 47 of Set 7 | hirado
# Processing Record 48 of Set 7 | balikpapan
# Processing Record 49 of Set 7 | aransas pass
# Processing Record 50 of Set 7 | taoudenni
# Processing Record 1 of Set 8 | rosarito
# Processing Record 2 of Set 8 | sudak
# Processing Record 3 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 4 of Set 8 | miandrivazo
# Processing Record 5 of Set 8 | arlit
# Processing Record 6 of Set 8 | hue
# Processing Record 7 of Set 8 | yerofey pavlovich
# Processing Record 8 of Set 8 | atagay
# Processing Record 9 of Set 8 | tuatapere
# Processing Record 10 of Set 8 | sydney
# Processing Record 11 of Set 8 | lorengau
# Processing Record 12 of Set 8 | gulshat
# City not found. Skipping...
# Processing Record 13 of Set 8 | hwange
# Processing Record 14 of Set 8 | hirara
# Processing Record 15 of Set 8 | vila do maio
# Processing Record 16 of Set 8 | evensk
# Processing Record 17 of Set 8 | clyde river
# Processing Record 18 of Set 8 | caramay
# Processing Record 19 of Set 8 | tecoanapa
# Processing Record 20 of Set 8 | safwah
# City not found. Skipping...
# Processing Record 21 of Set 8 | hualmay
# Processing Record 22 of Set 8 | culebra
# Processing Record 23 of Set 8 | massakory
# Processing Record 24 of Set 8 | bac lieu
# Processing Record 25 of Set 8 | the valley
# Processing Record 26 of Set 8 | naze
# Processing Record 27 of Set 8 | jumla
# Processing Record 28 of Set 8 | vaitupu
# City not found. Skipping...
# Processing Record 29 of Set 8 | half moon bay
# Processing Record 30 of Set 8 | rodos
# Processing Record 31 of Set 8 | formoso do araguaia
# City not found. Skipping...
# Processing Record 32 of Set 8 | xining
# Processing Record 33 of Set 8 | shingu
# Processing Record 34 of Set 8 | san-pedro
# Processing Record 35 of Set 8 | zyryanka
# Processing Record 36 of Set 8 | leningradskiy
# Processing Record 37 of Set 8 | morros
# Processing Record 38 of Set 8 | hudesti
# Processing Record 39 of Set 8 | kendal
# Processing Record 40 of Set 8 | batemans bay
# Processing Record 41 of Set 8 | ulaangom
# Processing Record 42 of Set 8 | esna
# Processing Record 43 of Set 8 | ulladulla
# Processing Record 44 of Set 8 | buraydah
# Processing Record 45 of Set 8 | grand gaube
# Processing Record 46 of Set 8 | kodinsk
# Processing Record 47 of Set 8 | dungarvan
# Processing Record 48 of Set 8 | vaitape
# Processing Record 49 of Set 8 | hay river
# Processing Record 50 of Set 8 | mombetsu
# Processing Record 1 of Set 9 | jutai
# Processing Record 2 of Set 9 | san policarpo
# Processing Record 3 of Set 9 | sorong
# Processing Record 4 of Set 9 | pacific grove
# Processing Record 5 of Set 9 | port blair
# Processing Record 6 of Set 9 | provideniya
# Processing Record 7 of Set 9 | carauari
# Processing Record 8 of Set 9 | leh
# Processing Record 9 of Set 9 | grindavik
# Processing Record 10 of Set 9 | ahipara
# Processing Record 11 of Set 9 | casablanca
# Processing Record 12 of Set 9 | belmonte
# Processing Record 13 of Set 9 | pontianak
# Processing Record 14 of Set 9 | pokaran
# Processing Record 15 of Set 9 | trelew
# Processing Record 16 of Set 9 | manaquiri
# Processing Record 17 of Set 9 | mandal
# Processing Record 18 of Set 9 | camapua
# Processing Record 19 of Set 9 | lompoc
# Processing Record 20 of Set 9 | constitucion
# Processing Record 21 of Set 9 | road town
# Processing Record 22 of Set 9 | galveston
# Processing Record 23 of Set 9 | virginia beach
# Processing Record 24 of Set 9 | coquimbo
# Processing Record 25 of Set 9 | grajau
# Processing Record 26 of Set 9 | mathbaria
# Processing Record 27 of Set 9 | lasa
# Processing Record 28 of Set 9 | grand centre
# City not found. Skipping...
# Processing Record 29 of Set 9 | chokwe
# Processing Record 30 of Set 9 | huazolotitlan
# City not found. Skipping...
# Processing Record 31 of Set 9 | chegdomyn
# Processing Record 32 of Set 9 | sri aman
# Processing Record 33 of Set 9 | tsiroanomandidy
# Processing Record 34 of Set 9 | werda
# Processing Record 35 of Set 9 | turbat
# Processing Record 36 of Set 9 | toliary
# City not found. Skipping...
# Processing Record 37 of Set 9 | katherine
# Processing Record 38 of Set 9 | mandalgovi
# Processing Record 39 of Set 9 | altay
# Processing Record 40 of Set 9 | nyurba
# Processing Record 41 of Set 9 | northam
# Processing Record 42 of Set 9 | nouakchott
# Processing Record 43 of Set 9 | calabozo
# Processing Record 44 of Set 9 | port hueneme
# Processing Record 45 of Set 9 | cruz alta
# Processing Record 46 of Set 9 | burica
# City not found. Skipping...
# Processing Record 47 of Set 9 | knin
# Processing Record 48 of Set 9 | yaan
# Processing Record 49 of Set 9 | assiniboia
# Processing Record 50 of Set 9 | calca
# Processing Record 1 of Set 10 | ankara
# Processing Record 2 of Set 10 | jibuti
# Processing Record 3 of Set 10 | buin
# Processing Record 4 of Set 10 | tabialan
# City not found. Skipping...
# Processing Record 5 of Set 10 | zavetnoye
# Processing Record 6 of Set 10 | ostrovnoy
# Processing Record 7 of Set 10 | panaba
# Processing Record 8 of Set 10 | port hardy
# Processing Record 9 of Set 10 | tawkar
# City not found. Skipping...
# Processing Record 10 of Set 10 | tual
# Processing Record 11 of Set 10 | tabas
# Processing Record 12 of Set 10 | talnakh
# Processing Record 13 of Set 10 | ketchikan
# Processing Record 14 of Set 10 | vangaindrano
# Processing Record 15 of Set 10 | tadine
# Processing Record 16 of Set 10 | hervey bay
# Processing Record 17 of Set 10 | sechelt
# Processing Record 18 of Set 10 | culipapa
# City not found. Skipping...
# Processing Record 19 of Set 10 | odweyne
# Processing Record 20 of Set 10 | khandyga
# Processing Record 21 of Set 10 | berezanka
# Processing Record 22 of Set 10 | safut
# Processing Record 23 of Set 10 | soure
# Processing Record 24 of Set 10 | bolshoye nagatkino
# Processing Record 25 of Set 10 | oussouye
# Processing Record 26 of Set 10 | salinopolis
# Processing Record 27 of Set 10 | santa maria
# Processing Record 28 of Set 10 | palmer
# Processing Record 29 of Set 10 | churachandpur
# Processing Record 30 of Set 10 | klichka
# Processing Record 31 of Set 10 | dingle
# Processing Record 32 of Set 10 | marabba
# Processing Record 33 of Set 10 | abdulino
# Processing Record 34 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 35 of Set 10 | barentu
# Processing Record 36 of Set 10 | galle
# Processing Record 37 of Set 10 | dudinka
# Processing Record 38 of Set 10 | jinchengjiang
# City not found. Skipping...
# Processing Record 39 of Set 10 | cayenne
# Processing Record 40 of Set 10 | paraibano
# Processing Record 41 of Set 10 | hobyo
# Processing Record 42 of Set 10 | nola
# Processing Record 43 of Set 10 | merauke
# Processing Record 44 of Set 10 | south sioux city
# Processing Record 45 of Set 10 | vao
# Processing Record 46 of Set 10 | kumluca
# Processing Record 47 of Set 10 | mareeba
# Processing Record 48 of Set 10 | la massana
# Processing Record 49 of Set 10 | floro
# Processing Record 50 of Set 10 | neuquen
# Processing Record 1 of Set 11 | san diego de la union
# Processing Record 2 of Set 11 | dali
# Processing Record 3 of Set 11 | yingcheng
# Processing Record 4 of Set 11 | moron
# Processing Record 5 of Set 11 | doha
# Processing Record 6 of Set 11 | umzimvubu
# City not found. Skipping...
# Processing Record 7 of Set 11 | solginskiy
# Processing Record 8 of Set 11 | imbituba
# Processing Record 9 of Set 11 | consuegra
# Processing Record 10 of Set 11 | lakefield
# Processing Record 11 of Set 11 | lavumisa
# Processing Record 12 of Set 11 | acapulco
# Processing Record 13 of Set 11 | maryborough
# Processing Record 14 of Set 11 | vanimo
# Processing Record 15 of Set 11 | tahlequah
# Processing Record 16 of Set 11 | basco
# Processing Record 17 of Set 11 | kuching
# Processing Record 18 of Set 11 | seoul
# Processing Record 19 of Set 11 | ngukurr
# City not found. Skipping...
# Processing Record 20 of Set 11 | sembakung
# Processing Record 21 of Set 11 | qujing
# Processing Record 22 of Set 11 | bandar-e lengeh
# Processing Record 23 of Set 11 | antsohihy
# Processing Record 24 of Set 11 | ratnagiri
# Processing Record 25 of Set 11 | srednekolymsk
# Processing Record 26 of Set 11 | harper
# Processing Record 27 of Set 11 | we
# City not found. Skipping...
# Processing Record 28 of Set 11 | torbay
# Processing Record 29 of Set 11 | kukuna
# Processing Record 30 of Set 11 | sola
# Processing Record 31 of Set 11 | san quintin
# Processing Record 32 of Set 11 | kifri
# Processing Record 33 of Set 11 | grand baie
# Processing Record 34 of Set 11 | peterhead
# Processing Record 35 of Set 11 | danielskuil
# Processing Record 36 of Set 11 | san isidro
# Processing Record 37 of Set 11 | camacha
# Processing Record 38 of Set 11 | halalo
# City not found. Skipping...
# Processing Record 39 of Set 11 | praia
# Processing Record 40 of Set 11 | aksarka
# Processing Record 41 of Set 11 | thinadhoo
# Processing Record 42 of Set 11 | henties bay
# Processing Record 43 of Set 11 | abu samrah
# Processing Record 44 of Set 11 | margate
# Processing Record 45 of Set 11 | panguipulli
# Processing Record 46 of Set 11 | port lincoln
# Processing Record 47 of Set 11 | kayerkan
# Processing Record 48 of Set 11 | ornskoldsvik
# Processing Record 49 of Set 11 | vermilion
# Processing Record 50 of Set 11 | kailua
# Processing Record 1 of Set 12 | arrifes
# Processing Record 2 of Set 12 | sorland
# Processing Record 3 of Set 12 | alice springs
# Processing Record 4 of Set 12 | maues
# Processing Record 5 of Set 12 | wamba
# Processing Record 6 of Set 12 | karasjok
# Processing Record 7 of Set 12 | dalbandin
# Processing Record 8 of Set 12 | atikokan
# Processing Record 9 of Set 12 | quesnel
# Processing Record 10 of Set 12 | ocos
# Processing Record 11 of Set 12 | parsons
# Processing Record 12 of Set 12 | bella vista
# Processing Record 13 of Set 12 | tessalit
# Processing Record 14 of Set 12 | tabarqah
# City not found. Skipping...
# Processing Record 15 of Set 12 | fevralsk
# City not found. Skipping...
# Processing Record 16 of Set 12 | kashi
# Processing Record 17 of Set 12 | denia
# Processing Record 18 of Set 12 | komsomolskiy
# Processing Record 19 of Set 12 | manokwari
# Processing Record 20 of Set 12 | kattivakkam
# Processing Record 21 of Set 12 | siilinjarvi
# Processing Record 22 of Set 12 | labuhan
# Processing Record 23 of Set 12 | lethbridge
# Processing Record 24 of Set 12 | lodwar
# Processing Record 25 of Set 12 | ontario
# Processing Record 26 of Set 12 | inongo
# Processing Record 27 of Set 12 | arroyo
# Processing Record 28 of Set 12 | andevoranto
# City not found. Skipping...
# Processing Record 29 of Set 12 | kabare
# Processing Record 30 of Set 12 | tezu
# Processing Record 31 of Set 12 | gotsu
# Processing Record 32 of Set 12 | makat
# Processing Record 33 of Set 12 | onega
# Processing Record 34 of Set 12 | takoradi
# Processing Record 35 of Set 12 | grenfell
# Processing Record 36 of Set 12 | warqla
# City not found. Skipping...
# Processing Record 37 of Set 12 | karaul
# City not found. Skipping...
# Processing Record 38 of Set 12 | sungaipenuh
# Processing Record 39 of Set 12 | podhum
# Processing Record 40 of Set 12 | talara
# Processing Record 41 of Set 12 | slave lake
# Processing Record 42 of Set 12 | chapayevka
# Processing Record 43 of Set 12 | san carlos de bariloche
# Processing Record 44 of Set 12 | kununurra
# Processing Record 45 of Set 12 | lillooet
# Processing Record 46 of Set 12 | wajir
# Processing Record 47 of Set 12 | willmar
# Processing Record 48 of Set 12 | puerto el triunfo
# Processing Record 49 of Set 12 | moroni
# Processing Record 50 of Set 12 | alugan
# Processing Record 1 of Set 13 | olot
# Processing Record 2 of Set 13 | sumenep
# Processing Record 3 of Set 13 | umm durman
# City not found. Skipping...
# Processing Record 4 of Set 13 | gigmoto
# Processing Record 5 of Set 13 | koungheul
# Processing Record 6 of Set 13 | hofn
# Processing Record 7 of Set 13 | mugur-aksy
# Processing Record 8 of Set 13 | edd
# Processing Record 9 of Set 13 | darnah
# Processing Record 10 of Set 13 | aguimes
# Processing Record 11 of Set 13 | wewak
# Processing Record 12 of Set 13 | bumbuna
# Processing Record 13 of Set 13 | guadalupe y calvo
# Processing Record 14 of Set 13 | adrar
# Processing Record 15 of Set 13 | pangkalanbuun
# Processing Record 16 of Set 13 | apen
# Processing Record 17 of Set 13 | tilichiki
# Processing Record 18 of Set 13 | masvingo
# Processing Record 19 of Set 13 | iquitos
# Processing Record 20 of Set 13 | paracuru
# Processing Record 21 of Set 13 | itaituba
# Processing Record 22 of Set 13 | svetlyy
# Processing Record 23 of Set 13 | cacu
# Processing Record 24 of Set 13 | boyolangu
# Processing Record 25 of Set 13 | lagoa
# Processing Record 26 of Set 13 | vizinga
# Processing Record 27 of Set 13 | nishihara
# Processing Record 28 of Set 13 | clonakilty
# Processing Record 29 of Set 13 | syedove
# Processing Record 30 of Set 13 | bambanglipuro
# Processing Record 31 of Set 13 | hunza
# City not found. Skipping...
# Processing Record 32 of Set 13 | mouzakion
# City not found. Skipping...
# Processing Record 33 of Set 13 | baoqing
# Processing Record 34 of Set 13 | nampula
# Processing Record 35 of Set 13 | yagodnoye
# Processing Record 36 of Set 13 | bilibino
# Processing Record 37 of Set 13 | pilna
# Processing Record 38 of Set 13 | innisfail
# Processing Record 39 of Set 13 | konongo
# Processing Record 40 of Set 13 | dryden
# Processing Record 41 of Set 13 | farafangana
# Processing Record 42 of Set 13 | boguchany
# Processing Record 43 of Set 13 | coxim
# Processing Record 44 of Set 13 | burgersdorp
# Processing Record 45 of Set 13 | zhenlai
# Processing Record 46 of Set 13 | fairbanks
# Processing Record 47 of Set 13 | guicheng
# City not found. Skipping...
# Processing Record 48 of Set 13 | bibiani
# Processing Record 49 of Set 13 | kachiry
# Processing Record 50 of Set 13 | felidhoo
# City not found. Skipping...
# Processing Record 1 of Set 14 | namatanai
# Processing Record 2 of Set 14 | nhulunbuy
# Processing Record 3 of Set 14 | taburi
# City not found. Skipping...
# Processing Record 4 of Set 14 | beringovskiy
# Processing Record 5 of Set 14 | mackay
# Processing Record 6 of Set 14 | mahanoro
# Processing Record 7 of Set 14 | kirensk
# Processing Record 8 of Set 14 | baza
# Processing Record 9 of Set 14 | inta
# Processing Record 10 of Set 14 | praya
# Processing Record 11 of Set 14 | weligama
# Processing Record 12 of Set 14 | bereda
# Processing Record 13 of Set 14 | ghanzi
# Processing Record 14 of Set 14 | kalmunai
# Processing Record 15 of Set 14 | camabatela
# Processing Record 16 of Set 14 | mazagao
# Processing Record 17 of Set 14 | hopelchen
# Processing Record 18 of Set 14 | matcha
# Processing Record 19 of Set 14 | lindi
# Processing Record 20 of Set 14 | bukama
# Processing Record 21 of Set 14 | guozhen
# Processing Record 22 of Set 14 | sao jose da coroa grande
# Processing Record 23 of Set 14 | cervo
# Processing Record 24 of Set 14 | salamanca
# Processing Record 25 of Set 14 | kisangani
# Processing Record 26 of Set 14 | puerto madero
# Processing Record 27 of Set 14 | soe
# Processing Record 28 of Set 14 | pahrump
# Processing Record 29 of Set 14 | teguise
# Processing Record 30 of Set 14 | inverell
# Processing Record 31 of Set 14 | saint-georges
# Processing Record 32 of Set 14 | troon
# Processing Record 33 of Set 14 | gulu
# Processing Record 34 of Set 14 | kimbe
# Processing Record 35 of Set 14 | banjar
# Processing Record 36 of Set 14 | cairns
# Processing Record 37 of Set 14 | concord
# Processing Record 38 of Set 14 | meulaboh
# Processing Record 39 of Set 14 | salalah
# Processing Record 40 of Set 14 | shemonaikha
# Processing Record 41 of Set 14 | erken-shakhar
# City not found. Skipping...
# Processing Record 42 of Set 14 | gunjur
# Processing Record 43 of Set 14 | marcona
# City not found. Skipping...
# Processing Record 44 of Set 14 | besancon
# Processing Record 45 of Set 14 | honiara
# Processing Record 46 of Set 14 | rognan
# Processing Record 47 of Set 14 | lufilufi
# Processing Record 48 of Set 14 | jalu
# Processing Record 49 of Set 14 | erzincan
# Processing Record 50 of Set 14 | mbanza-ngungu
# Processing Record 1 of Set 15 | vitim
# Processing Record 2 of Set 15 | uyskoye
# Processing Record 3 of Set 15 | los llanos de aridane
# Processing Record 4 of Set 15 | ojinaga
# Processing Record 5 of Set 15 | namie
# Processing Record 6 of Set 15 | la ronge
# Processing Record 7 of Set 15 | mehamn
# Processing Record 8 of Set 15 | gola gokarannath
# Processing Record 9 of Set 15 | santa isabel do rio negro
# Processing Record 10 of Set 15 | ternate
# Processing Record 11 of Set 15 | pasuquin
# Processing Record 12 of Set 15 | la primavera
# Processing Record 13 of Set 15 | north platte
# Processing Record 14 of Set 15 | abha
# Processing Record 15 of Set 15 | minab
# Processing Record 16 of Set 15 | akdepe
# Processing Record 17 of Set 15 | moa
# Processing Record 18 of Set 15 | lusambo
# Processing Record 19 of Set 15 | yining
# Processing Record 20 of Set 15 | marolambo
# Processing Record 21 of Set 15 | arman
# Processing Record 22 of Set 15 | novikovo
# Processing Record 23 of Set 15 | kremenchuk
# Processing Record 24 of Set 15 | maridi
# Processing Record 25 of Set 15 | kutum
# Processing Record 26 of Set 15 | mayo
# Processing Record 27 of Set 15 | sechura
# Processing Record 28 of Set 15 | lavrentiya
# Processing Record 29 of Set 15 | pascagoula
# Processing Record 30 of Set 15 | hovd
# Processing Record 31 of Set 15 | caravelas
# Processing Record 32 of Set 15 | talaya
# Processing Record 33 of Set 15 | poopo
# Processing Record 34 of Set 15 | mattru
# Processing Record 35 of Set 15 | chiredzi
# Processing Record 36 of Set 15 | melfi
# Processing Record 37 of Set 15 | gambela
# Processing Record 38 of Set 15 | mudyuga
# City not found. Skipping...
# Processing Record 39 of Set 15 | nicolas bravo
# Processing Record 40 of Set 15 | san rafael
# Processing Record 41 of Set 15 | gobabis
# Processing Record 42 of Set 15 | touros
# Processing Record 43 of Set 15 | izumo
# Processing Record 44 of Set 15 | husavik
# Processing Record 45 of Set 15 | bolungarvik
# City not found. Skipping...
# Processing Record 46 of Set 15 | grand-bourg
# Processing Record 47 of Set 15 | muriti
# Processing Record 48 of Set 15 | comodoro rivadavia
# Processing Record 49 of Set 15 | warrnambool
# Processing Record 50 of Set 15 | tarpon springs
# Processing Record 1 of Set 16 | aden
# Processing Record 2 of Set 16 | khani
# Processing Record 3 of Set 16 | adre
# Processing Record 4 of Set 16 | mutsamudu
# City not found. Skipping...
# Processing Record 5 of Set 16 | grand forks
# Processing Record 6 of Set 16 | sept-iles
# Processing Record 7 of Set 16 | alekseyevka
# Processing Record 8 of Set 16 | san jeronimo
# Processing Record 9 of Set 16 | san andres
# Processing Record 10 of Set 16 | verkhnyaya inta
# Processing Record 11 of Set 16 | gayeri
# Processing Record 12 of Set 16 | custodia
# Processing Record 13 of Set 16 | bouca
# Processing Record 14 of Set 16 | port macquarie
# Processing Record 15 of Set 16 | okha
# Processing Record 16 of Set 16 | morwa
# Processing Record 17 of Set 16 | brignoles
# Processing Record 18 of Set 16 | raudeberg
# Processing Record 19 of Set 16 | kaduqli
# Processing Record 20 of Set 16 | izmit
# Processing Record 21 of Set 16 | sheregesh
# Processing Record 22 of Set 16 | carlisle
# Processing Record 23 of Set 16 | zhezkazgan
# Processing Record 24 of Set 16 | nongan
# Processing Record 25 of Set 16 | inuvik
# Processing Record 26 of Set 16 | general cepeda
# Processing Record 27 of Set 16 | altona
# Processing Record 28 of Set 16 | sabang
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# 6.2.7 Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0       Hasaki  35.7333  140.8333     66.60        81         100        5.41
# 1    Carnarvon -24.8667  113.6333     60.87        82          98        5.75
# 2     Hamilton  39.1834  -84.5333     84.78        53          20        1.99
# 3       Faanui -16.4833 -151.7500     80.83        73          99        8.50
# 4     Hermanus -34.4187   19.2345     53.80        59           0        4.38
# 5   Codrington -38.2667  141.9667     52.97        90         100        7.78
# 6        Vaini -21.2000 -175.2000     64.56        94          20        1.14
# 7  Port Alfred -33.5906   26.8910     61.88        81           0       13.69
# 8  Tuktoyaktuk  69.4541 -133.0374     33.80        86          90       13.80
# 9    Jamestown  42.0970  -79.2353     83.08        44           1       16.11
#
#   Country Current Description
# 0      JP     overcast clouds
# 1      AU     overcast clouds
# 2      US          few clouds
# 3      PF     overcast clouds
# 4      ZA           clear sky
# 5      AU     overcast clouds
# 6      TO          few clouds
# 7      ZA           clear sky
# 8      CA     overcast clouds
# 9      US           clear sky

# %%
# reorder the columns - you may use the SAME df name, you do NOT need to rename the dataframe, as shown below
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]

# %%
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Hasaki      JP  35.7333  140.8333     66.60        81         100
# 1    Carnarvon      AU -24.8667  113.6333     60.87        82          98
# 2     Hamilton      US  39.1834  -84.5333     84.78        53          20
# 3       Faanui      PF -16.4833 -151.7500     80.83        73          99
# 4     Hermanus      ZA -34.4187   19.2345     53.80        59           0
# 5   Codrington      AU -38.2667  141.9667     52.97        90         100
# 6        Vaini      TO -21.2000 -175.2000     64.56        94          20
# 7  Port Alfred      ZA -33.5906   26.8910     61.88        81           0
# 8  Tuktoyaktuk      CA  69.4541 -133.0374     33.80        86          90
# 9    Jamestown      US  42.0970  -79.2353     83.08        44           1
#
#    Wind Speed Current Description
# 0        5.41     overcast clouds
# 1        5.75     overcast clouds
# 2        1.99          few clouds
# 3        8.50     overcast clouds
# 4        4.38           clear sky
# 5        7.78     overcast clouds
# 6        1.14          few clouds
# 7       13.69           clear sky
# 8       13.80     overcast clouds
# 9       16.11           clear sky

# %%
# Create the output file (CSV).
output_data_file = "weather_database/WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
